# %% [markdown]
# ### Importing all the required libraries.

# %%
import numpy as np 
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json 
from geopy.geocoders import Nominatim # converts an address into latitude and longitude values

import requests 
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans
import folium

# %%
with open('NYC.json') as json_data:
    nyc_data = json.load(json_data)

# %%
ngh_data = nyc_data['features']

# %% [markdown]
# Defining the columns of the dataframe

# %%
cols = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
nghs = pd.DataFrame(columns=cols)
nghs
# Out:
# Empty DataFrame
# Columns: [Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %%
for data in ngh_data:
    bgh = ngh_name = data['properties']['borough'] 
    ngh_name = data['properties']['name']
        
    ngh_lat_long = data['geometry']['coordinates']
    ngh_lat = ngh_lat_long[1]
    ngh_long = ngh_lat_long[0]
    
    nghs = nghs.append({'Borough': bgh,
                        'Neighborhood': ngh_name,
                        'Latitude': ngh_lat,
                        'Longitude': ngh_long}, ignore_index=True)

# %%
nghs.head(11)
# Out:
#       Borough    Neighborhood   Latitude  Longitude
# 0       Bronx       Wakefield  40.894705 -73.847201
# 1       Bronx      Co-op City  40.874294 -73.829939
# 2       Bronx     Eastchester  40.887556 -73.827806
# 3       Bronx       Fieldston  40.895437 -73.905643
# 4       Bronx       Riverdale  40.890834 -73.912585
# 5       Bronx     Kingsbridge  40.881687 -73.902818
# 6   Manhattan     Marble Hill  40.876551 -73.910660
# 7       Bronx        Woodlawn  40.898273 -73.867315
# 8       Bronx         Norwood  40.877224 -73.879391
# 9       Bronx  Williamsbridge  40.881039 -73.857446
# 10      Bronx      Baychester  40.866858 -73.835798

# %% [markdown]
# Now, making use of the geopy library to obtain the latitude and longitude values of NYC

# %%
add = 'New York City, NY'
geoloc = Nominatim(user_agent="ny_explorer")
loc = geoloc.geocode(add)
latitude = loc.latitude
longitude = loc.longitude
print('The Latitude & longitude values of NYC are {}, {}.'.format(latitude, longitude))
# Out:
# The Latitude & longitude values of NYC are 40.7127281, -74.0060152.

# %% [markdown]
# Creating a map of NYC using latitude and longitude values

# %%
map_nyc = folium.Map(location=[latitude, longitude], zoom_start=10)

# adding markers to map of NYC
for lat, lng, bgh, ngh in zip(nghs['Latitude'], nghs['Longitude'], nghs['Borough'], nghs['Neighborhood']):
    label = '{}, {}'.format(ngh, bgh)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = 'blue',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7,
        parse_html = False).add_to(map_nyc)  
    
map_nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Using the client id, client secret and version details from foursquare

# %%
client_id = 'FNOIZT3LLD1JMD4PYLSRH4H3AL5BRN2ECW1BC0S0YLUZAHMR' 
client_secret = 'K0GXEFGYMEJXKIVBCNRCHSU0ILTBPLISWVI2SQIFJUEBODEX'
version = '20180605'

# %%
lim = 500 
bghs = ["Bronx","Manhattan","Brooklyn","Queens","Staten Island"]
result = {}
for bgh in bghs:
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&near={}&limit={}&categoryId={}'.format(
        client_id, 
        client_secret, 
        version, 
        bgh,
        lim,
        "4c2cd86ed066bed06c3c5209") # gluten-free restaurants category id from foursquare
    result[bgh] = requests.get(url).json()

# %%
venues_df={} 
for bgh in bghs:
    venues = json_normalize(result[bgh]['response']['groups'][0]['items'])
    venues_df[bgh] = venues[['venue.name', 'venue.location.address', 'venue.location.lat', 'venue.location.lng']]
    venues_df[bgh].columns = ['Name', 'Address', 'Lat', 'Lng']

venues_df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# {'Bronx':                                 Name                             Address  \
#  0                Mighty Oak Roasters                       2801 24th Ave
#  1                    The Health Nuts                      21135 26th Ave
#  2                        Candle Cafe                        1307 3rd Ave
#  3                            Tap NYC                    267 Columbus Ave
#  4                      Kome Waza UES                        1275 1st Ave
#  5                              Noglu                    1266 Madison Ave
#  6                       Beyond Sushi                        62 W 56th St
#  7                          by CHLOE.                   1 Rockefeller Plz
#  8      Mario's Restaurant & Catering                     2342 Arthur Ave
#  9                    The Little Beet                       1140 Broadway
#  10                One Stop Beer Shop                   134 Kingsland Ave
#  11             The Little Beet Table                      333 Park Ave S
#  12               Rubirosa Ristorante                     235 Mulberry St
#  13                          Bistango                         415 3rd Ave
#  14                Kesté Pizza & Vino                     271 Bleecker St
#  15                             Nizza                         630 9th Ave
#  16              UNO Pizzeria & Grill                    432 Columbus Ave
#  17                 The Organic Grill                         123 1st Ave
#  18                        Hu Kitchen                       78 5th Avenue
#  19                             S'MAC                         197 1st Ave
#  20               Bombay Sandwich Co.                        48 W 27th St
#  21                        Kimbap Lab                  238 Bedford Avenue
#  22              Paisano's Ristorante                        132 Park Ave
#  23                   The Little Beet                       135 W 50th St
#  24                 Between The Bread                       20A E 40th St
#  25                          Bistango                       145 E 50th St
#  26                        Exhibit C.                      88 Eldridge St
#  27              Uno Pizzeria & Grill                     39-02 Bell Blvd
#  28                             ROLLN                        38 E 23rd St
#  29                   The Little Beet                       111 W 40th St
#  30                      Senza Gluten                     206 Sullivan St
#  31                   Red Barn Bakery                        4 S Astor St
#  32              UNO Pizzeria & Grill  426 Route 3 West Riverfront Center
#  33                              Wild                    535 Hudson St #A
#  34  Davio's North Italian Steakhouse                   447 Lexington Ave
#  35                 Posh Pop Bakeshop                     192 Bleecker St
#  36                FRESH Healthy Cafe                        77 Hudson St
#  37                      Stir-licious                    712 North Avenue
#  38                              Arba                    472 Columbus Ave
#  39                 Bradley Bake Shop                         55 River Rd
#  40                       Bex Waffles                            Broadway
#  41             Audrey's Añple Apples                         11 Avenue A
#  42                           Dee Daa                       132 W 31st St
#  43                         Red Mango                      111 Fulton St.
#  44            Capo Ristorante Panino                       49 Covert Ave
#  45                    Twibar Falafel                                 NaN
#  46         The Modern Primitive Cafe                         254 36th St
#
#            Lat        Lng
#  0   40.773495 -73.916809
#  1   40.778788 -73.778426
#  2   40.771407 -73.959138
#  3   40.777723 -73.978567
#  4   40.765602 -73.957403
#  5   40.783801 -73.956687
#  6   40.763454 -73.977163
#  7   40.758063 -73.978854
#  8   40.854244 -73.888437
#  9   40.743914 -73.988746
#  10  40.720990 -73.940829
#  11  40.741110 -73.985344
#  12  40.722706 -73.995957
#  13  40.742370 -73.980286
#  14  40.731542 -74.002953
#  15  40.760100 -73.991378
#  16  40.783176 -73.974645
#  17  40.727306 -73.985539
#  18  40.735795 -73.993944
#  19  40.730227 -73.983696
#  20  40.745184 -73.990644
#  21  40.716160 -73.959530
#  22  40.826804 -74.106062
#  23  40.760990 -73.982246
#  24  40.751621 -73.980754
#  25  40.756266 -73.971339
#  26  40.717189 -74.003042
#  27  40.765087 -73.771871
#  28  40.740656 -73.987310
#  29  40.753998 -73.985660
#  30  40.728926 -74.000257
#  31  41.038069 -73.873031
#  32  40.830685 -74.139572
#  33  40.734631 -74.006129
#  34  40.753233 -73.974774
#  35  40.729224 -74.001538
#  36  40.714458 -74.034545
#  37  40.925662 -73.788869
#  38  40.784231 -73.974037
#  39  40.871229 -74.033008
#  40  40.754658 -73.986717
#  41  40.749777 -74.006696
#  42  40.748475 -73.990267
#  43  40.709832 -74.006761
#  44  40.721596 -73.688444
#  45  40.663440 -73.957535
#  46  40.656078 -74.007109  ,
#  'Manhattan':                                      Name                      Address  \
#  0                                Bistango                  415 3rd Ave
#  1                   The Little Beet Table               333 Park Ave S
#  2                              Hu Kitchen                78 5th Avenue
#  3                                   Nizza                  630 9th Ave
#  4                                   S'MAC                  197 1st Ave
#  5                                   Noglu             1266 Madison Ave
#  6                             Candle Cafe                 1307 3rd Ave
#  7                               by CHLOE.            1 Rockefeller Plz
#  8                         The Little Beet                1140 Broadway
#  9                            Beyond Sushi                 62 W 56th St
#  10                                Tap NYC             267 Columbus Ave
#  11                 Don Antonio by Starita                309 W 50th St
#  12                             Friedman's                132 W 31st St
#  13                     Kesté Pizza & Vino              271 Bleecker St
#  14                    Rubirosa Ristorante              235 Mulberry St
#  15                          Kome Waza UES                 1275 1st Ave
#  16            The Grey Dog - Union Square             90 University Pl
#  17                      By the Way Bakery                2442 Broadway
#  18                    Bombay Sandwich Co.                 48 W 27th St
#  19                               Bistango                145 E 50th St
#  20                                  Terri                 60 W 23rd St
#  21                           Schmackary's                362 W 45th St
#  22                                Ribalta                 48 E 12th St
#  23                   UNO Pizzeria & Grill             432 Columbus Ave
#  24                 The Grey Dog - Chelsea                242 W 16th St
#  25                      Between The Bread                20A E 40th St
#  26                                  ROLLN                 38 E 23rd St
#  27                               Maialino              2 Lexington Ave
#  28                        The Little Beet                135 W 50th St
#  29                           Senza Gluten              206 Sullivan St
#  30                        The Little Beet                111 W 40th St
#  31                      The Organic Grill                  123 1st Ave
#  32                       Friedman's Lunch                   75 9th Ave
#  33                  Erin McKenna's Bakery                248 Broome St
#  34                                 O Cafe   482 Avenue of the Americas
#  35            Sottocasa Pizzeria - Harlem           227 Malcolm X Blvd
#  36                   Bar Suzette Creperie               Chelsea Market
#  37                              Melt Shop                 55 W 26th St
#  38                 The Butcher's Daughter                581 Hudson St
#  39                    Pisticci Ristorante              125 La Salle St
#  40                          Rossopomodoro            118 Greenwich Ave
#  41                                Dig Inn                150 E 52nd St
#  42                        Blossom Du Jour                  617 9th Ave
#  43                             Pizza Park                 1233 1st Ave
#  44                         Billy's Bakery                  184 9th Ave
#  45                               Pizzarte                 69 W 55th St
#  46                     Risotteria Melotti                 309 E 5th St
#  47                            San Marzano                  117 2nd Ave
#  48                       Luigi's Pizzeria                 1701 1st Ave
#  49                             Exhibit C.               88 Eldridge St
#  50                                Emporio                  231 Mott St
#  51                      The Meatball Shop             64 Greenwich Ave
#  52                              Del Posto                  85 10th Ave
#  53                        John's Pizzeria                260 W 44th St
#  54                    Barilla Restaurants  1290 Avenue of the Americas
#  55                 The Butcher's Daughter                19 Kenmare St
#  56                             Bareburger                  153 8th Ave
#  57                            The Counter                   7 Times Sq
#  58                    Big Booty Bread Co.                261 W 23rd St
#  59                        Eataly Flatiron                  200 5th Ave
#  60                        Pizza By Cer Tè                132 E 56th St
#  61                              Il Mulino                 37 E 60th St
#  62                             Cafe Cluny                284 W 12th St
#  63                        Quality Italian                 57 W 57th St
#  64                                   Wild             535 Hudson St #A
#  65                        Magnolia Bakery              401 Bleecker St
#  66                               Egg Shop             151 Elizabeth St
#  67                       Bocca Restaurant                  39E 19th St
#  68                  Bleecker Street Pizza                 69 7th Ave S
#  69                     Souen East Village                 326 E 6th St
#  70                         Bluestone Lane                 1085 5th Ave
#  71                             Olio e Piú              3 Greenwich Ave
#  72                         Bluestone Lane                 902 Broadway
#  73                             Bar Italia              768 Madison Ave
#  74                             Sarabeth's            40 Central Park S
#  75  Heidi's House By The Side Of The Road                308 E 78th St
#  76       Davio's North Italian Steakhouse            447 Lexington Ave
#  77            The Grey Dog - West Village                49 Carmine St
#  78                                Bel Ami                 30 E 68th St
#  79                Little Cupcake Bakeshop                 30 Prince St
#  80                        5 Napkin Burger                  630 9th Ave
#  81                          Cafe Fiorello                1900 Broadway
#  82                             Friedman's           1187 Amsterdam Ave
#  83                       Galli Restaurant                 45 Mercer St
#  84                 Corrado Bread & Pastry           1361 Lexington Ave
#  85                         The Ginger Man                 11 E 36th St
#  86                         Blossom Bakery                  174 9th Ave
#  87                     Buddha Bodai 佛菩提素菜                    5 Mott St
#  88                  John's of 12th Street                302 E 12th St
#  89                   Pershing Square Café                 90 E 42nd St
#  90                              Bar Primi                   325 Bowery
#  91                 Big Gay Ice Cream Shop                 125 E 7th St
#  92                             Nice Matin                201 W 79th St
#  93                      Le Pain Quotidien                 70 W 40th St
#  94                 Dominique Ansel Bakery                189 Spring St
#  95                                  Indie            43-10 Crescent St
#  96                         Bluestone Lane                30 Carmine St
#  97             Paesano of Mulberry Street              136 Mulberry St
#  98                      Le Pain Quotidien                  7 E 53rd St
#  99                         Cafe du Soleil                2723 Broadway
#
#            Lat        Lng
#  0   40.742370 -73.980286
#  1   40.741110 -73.985344
#  2   40.735795 -73.993944
#  3   40.760100 -73.991378
#  4   40.730227 -73.983696
#  5   40.783801 -73.956687
#  6   40.771407 -73.959138
#  7   40.758063 -73.978854
#  8   40.743914 -73.988746
#  9   40.763454 -73.977163
#  10  40.777723 -73.978567
#  11  40.762718 -73.986708
#  12  40.748626 -73.990283
#  13  40.731542 -74.002953
#  14  40.722706 -73.995957
#  15  40.765602 -73.957403
#  16  40.733701 -73.992974
#  17  40.790965 -73.974491
#  18  40.745184 -73.990644
#  19  40.756266 -73.971339
#  20  40.742529 -73.992312
#  21  40.760070 -73.990815
#  22  40.733258 -73.991664
#  23  40.783176 -73.974645
#  24  40.740602 -74.000698
#  25  40.751621 -73.980754
#  26  40.740656 -73.987310
#  27  40.738442 -73.985610
#  28  40.760990 -73.982246
#  29  40.728926 -74.000257
#  30  40.753998 -73.985660
#  31  40.727306 -73.985539
#  32  40.742523 -74.006403
#  33  40.718001 -73.989755
#  34  40.735826 -73.997713
#  35  40.805550 -73.947435
#  36  40.742324 -74.006383
#  37  40.745008 -73.990883
#  38  40.736328 -74.005860
#  39  40.814015 -73.960266
#  40  40.738587 -74.002252
#  41  40.757228 -73.970721
#  42  40.759434 -73.991848
#  43  40.764305 -73.958503
#  44  40.745374 -74.002119
#  45  40.762896 -73.977741
#  46  40.726572 -73.988499
#  47  40.728076 -73.988234
#  48  40.778222 -73.948426
#  49  40.717189 -74.003042
#  50  40.722633 -73.995125
#  51  40.736086 -74.000841
#  52  40.743439 -74.007449
#  53  40.758272 -73.988654
#  54  40.761146 -73.979155
#  55  40.720593 -73.994906
#  56  40.742069 -74.001098
#  57  40.755228 -73.986747
#  58  40.745046 -73.997824
#  59  40.741987 -73.989913
#  60  40.760488 -73.969878
#  61  40.764028 -73.970400
#  62  40.737538 -74.003897
#  63  40.764513 -73.976827
#  64  40.734631 -74.006129
#  65  40.735886 -74.005149
#  66  40.720431 -73.994977
#  67  40.738133 -73.989013
#  68  40.732268 -74.003589
#  69  40.726828 -73.987196
#  70  40.783757 -73.958526
#  71  40.733873 -73.999599
#  72  40.739372 -73.989482
#  73  40.767856 -73.968323
#  74  40.765237 -73.975456
#  75  40.772481 -73.955053
#  76  40.753233 -73.974774
#  77  40.729932 -74.004010
#  78  40.769104 -73.967041
#  79  40.722951 -73.994910
#  80  40.760180 -73.991095
#  81  40.771735 -73.981996
#  82  40.808332 -73.959943
#  83  40.721607 -74.001235
#  84  40.781976 -73.953761
#  85  40.749355 -73.982793
#  86  40.745018 -74.002500
#  87  40.713798 -73.998677
#  88  40.730840 -73.985530
#  89  40.751783 -73.977937
#  90  40.725661 -73.991761
#  91  40.726287 -73.984114
#  92  40.783302 -73.978383
#  93  40.753151 -73.984574
#  94  40.725163 -74.002976
#  95  40.748895 -73.942162
#  96  40.730009 -74.002855
#  97  40.718658 -73.997636
#  98  40.760277 -73.975011
#  99  40.800010 -73.968094  ,
#  'Brooklyn':                                         Name                 Address  \
#  0                         One Stop Beer Shop       134 Kingsland Ave
#  1                                 Kimbap Lab      238 Bedford Avenue
#  2                               Champs Diner         197 Meserole St
#  3                             Everybody Eats             294 3rd Ave
#  4                          Clementine Bakery          299 Greene Ave
#  5                          Vinnie's Pizzeria         148 Bedford Ave
#  6                                      Testo          141 Leonard St
#  7                              Natural Blend     769A Washington Ave
#  8                                 Luzzo's BK        145 Atlantic Ave
#  9                                 Bunna Cafe       1084 Flushing Ave
#  10                                Pizza Plus             359 7th Ave
#  11                        Caprices by Sophie            138 N 6th St
#  12                                Baby Skips         1158 Myrtle Ave
#  13                               Wild Ginger            112 Smith St
#  14                         The Meatball Shop         170 Bedford Ave
#  15                                The V Spot             156 5th Ave
#  16                              Dellarocco's            214 Hicks St
#  17                        Sottocasa Pizzeria        298 Atlantic Ave
#  18                        Williamsburg Pizza           265 Union Ave
#  19                          Lean Crust Pizza           737 Fulton St
#  20                               Graziella's      232 Vanderbilt Ave
#  21                  Giovanni's Brooklyn Eats            1657 8th Ave
#  22                    Little Choc Apothecary        141 Havemeyer St
#  23                                    Ovenly       31 Greenpoint Ave
#  24                                sweetgreen            162 N 4th St
#  25                                   Oregano            102 Berry St
#  26                                   Pitanga            207 Starr St
#  27                       Screamer's Pizzeria       620 Manhattan Ave
#  28                          Randazzo's Pizza          306 Ditmas Ave
#  29                      UNO Pizzeria & Grill            9201 4th Ave
#  30                              Tasty Pastry           8218 13th Ave
#  31                                 Fabiane's            142 N 5th St
#  32                         Baked In Brooklyn             755 5th Ave
#  33                                    Barano             26 Broadway
#  34                                Mama Rao's           6408 11th Ave
#  35                                     Baked        359 Van Brunt St
#  36                                 Konditori            114 Smith St
#  37                                   Shelter             80 N 7th St
#  38                                    Anella         222 Franklin St
#  39                              Pizza Studio                     NaN
#  40                   Little Cupcake Bakeshop      598 Vanderbilt Ave
#  41                      Buttermilk Bake Shop             260 5th Ave
#  42                             Urban Vintage           294 Grand Ave
#  43                               Der Pioneer          737 Church Ave
#  44             Da Nonna Rosa Cucina Italiana             140 7th Ave
#  45                             Choice Market       318 Lafayette Ave
#  46                                   Sidecar             560 5th Ave
#  47                               Han Dynasty            445 Albee Sq
#  48                            Tamra Teahouse          1524 Bergen St
#  49                             Graham Market          247 Graham Ave
#  50                    Naidre's Cafe & Bakery             384 7th Ave
#  51                                  Crema BK          182 Driggs Ave
#  52                              Reunion Cafe           544 Union Ave
#  53                                    Gather             341 7th Ave
#  54                 La Nonna Ristorante & Bar            184 Kent Ave
#  55                                   Baoburg       614 Manhattan Ave
#  56                  DaleView Biscuits & Beer       1170 Nostrand Ave
#  57                      Two Boots Park Slope             284 5th Ave
#  58             Stonefruit Espresso + Kitchen        1058 Bedford Ave
#  59                                 Konditori      696 Washington Ave
#  60                      Bagel Pub Park Slope              287 9th St
#  61                        Front Street Pizza             80 Front St
#  62                          Juice Generation         210 Bedford Ave
#  63                        Dinosaur Bar-B-Que            604 Union St
#  64                                 Sweatshop    232 Metropolitan Ave
#  65                      Court Street Grocers            485 Court St
#  66                                Mr. Kiwi's            957 Broadway
#  67                               Sweet Rosie           3512 Avenue S
#  68                            baba cool cafe  64 Lafayette Ave Ste B
#  69                                Coffee Mob        1514 Newkirk Ave
#  70                          Pizza Cotta-Bene             291 3rd Ave
#  71                                Lula Bagel        816 Nostrand Ave
#  72                                  Elk Cafe    154 Prospect Park SW
#  73                               Pure Bistro              88 5th Ave
#  74                              Salem's Hour       1110 Nostrand Ave
#  75                                Moo Burger            240 Court St
#  76                           The Wicked Monk            9510 3rd Ave
#  77                            The Wheelhouse          165 Wilson Ave
#  78                                 Green Ivy             244 4th Ave
#  79                      Ample Hills Creamery      623 Vanderbilt Ave
#  80                                   Stocked      635 Vanderbilt Ave
#  81  Hanco's Bubble Tea & Vietnamese Sandwich             350 7th Ave
#  82                                      LARK         1007 Church Ave
#  83                                Bagelsmith          566 Lorimer St
#  84                 The Modern Primitive Cafe             254 36th St
#  85                           Absolute Coffee        327 Atlantic Ave
#  86             Van Leeuwen Artisan Ice Cream       620 Manhattan Ave
#  87          Brooklyn Farmacy & Soda Fountain            513 Henry St
#  88                    Fuel Energy Restaurant            7004 3rd Ave
#  89                   Raaka Chocolate Factory          64 Seabring St
#  90                               Stoop Juice             443 7th Ave
#  91                                Bareburger             170 7th Ave
#  92                            Twibar Falafel                     NaN
#  93                                  Tanoreen            7523 3rd Ave
#  94                        Washington Commons      748 Washington Ave
#  95                                 Pio Bagel         136 Lawrence St
#  96         Tortilleria Mexicana Los Hermanos            271 Starr St
#  97                  Wholesome Gourmet Market        534 Flatbush Ave
#  98                      two8two Bar & Burger        282 Atlantic Ave
#  99                                 The Woods             48 S 4th St
#
#            Lat        Lng
#  0   40.720990 -73.940829
#  1   40.716160 -73.959530
#  2   40.708335 -73.940816
#  3   40.677020 -73.986594
#  4   40.687473 -73.959748
#  5   40.718849 -73.956643
#  6   40.708320 -73.946990
#  7   40.673819 -73.962923
#  8   40.690555 -73.995333
#  9   40.705012 -73.928068
#  10  40.665947 -73.982361
#  11  40.717805 -73.959128
#  12  40.697213 -73.933616
#  13  40.687898 -73.989730
#  14  40.718170 -73.957502
#  15  40.678057 -73.979392
#  16  40.694992 -73.995924
#  17  40.688534 -73.988947
#  18  40.708303 -73.950699
#  19  40.686579 -73.975108
#  20  40.690501 -73.969438
#  21  40.660159 -73.983753
#  22  40.711956 -73.957333
#  23  40.729708 -73.959544
#  24  40.715804 -73.959234
#  25  40.719038 -73.958557
#  26  40.705071 -73.923324
#  27  40.723558 -73.950710
#  28  40.635815 -73.975723
#  29  40.618065 -74.030028
#  30  40.616052 -74.012058
#  31  40.716731 -73.958939
#  32  40.658807 -73.996232
#  33  40.710370 -73.967940
#  34  40.629048 -74.005683
#  35  40.676959 -74.013327
#  36  40.687832 -73.989777
#  37  40.719678 -73.960778
#  38  40.733272 -73.958019
#  39  40.653577 -73.871486
#  40  40.678468 -73.968684
#  41  40.674794 -73.981643
#  42  40.687974 -73.962710
#  43  40.645911 -73.972028
#  44  40.672872 -73.976732
#  45  40.688438 -73.962873
#  46  40.665321 -73.989563
#  47  40.691334 -73.982456
#  48  40.675009 -73.932875
#  49  40.710789 -73.943862
#  50  40.665392 -73.982859
#  51  40.723001 -73.945727
#  52  40.716798 -73.951934
#  53  40.666578 -73.981901
#  54  40.718573 -73.963751
#  55  40.723537 -73.950414
#  56  40.658921 -73.950757
#  57  40.674099 -73.982343
#  58  40.688832 -73.955061
#  59  40.677190 -73.963693
#  60  40.669526 -73.986995
#  61  40.702523 -73.989640
#  62  40.717016 -73.958809
#  63  40.677567 -73.984096
#  64  40.715090 -73.959734
#  65  40.676287 -73.998807
#  66  40.696879 -73.934934
#  67  40.609508 -73.931739
#  68  40.687014 -73.975255
#  69  40.635841 -73.962561
#  70  40.677055 -73.986346
#  71  40.670894 -73.950596
#  72  40.654944 -73.973308
#  73  40.680347 -73.977837
#  74  40.660644 -73.950648
#  75  40.685845 -73.994229
#  76  40.617129 -74.033849
#  77  40.699997 -73.924401
#  78  40.676677 -73.983605
#  79  40.678547 -73.968455
#  80  40.678104 -73.968678
#  81  40.666375 -73.982142
#  82  40.646811 -73.970043
#  83  40.713986 -73.949333
#  84  40.656078 -74.007109
#  85  40.688079 -73.987693
#  86  40.723599 -73.950706
#  87  40.684071 -73.999309
#  88  40.634807 -74.026524
#  89  40.681334 -74.007436
#  90  40.663203 -73.984657
#  91  40.671900 -73.977620
#  92  40.663440 -73.957535
#  93  40.630726 -74.027954
#  94  40.675597 -73.963385
#  95  40.692159 -73.986368
#  96  40.706548 -73.921913
#  97  40.660939 -73.961076
#  98  40.688513 -73.989743
#  99  40.712914 -73.966359  ,
#  'Queens':                                 Name                             Address  \
#  0                        Candle Cafe                        1307 3rd Ave
#  1                Mighty Oak Roasters                       2801 24th Ave
#  2                    The Health Nuts                      21135 26th Ave
#  3                      Kome Waza UES                        1275 1st Ave
#  4                           Bistango                         415 3rd Ave
#  5                  Between The Bread                       20A E 40th St
#  6                 One Stop Beer Shop                   134 Kingsland Ave
#  7                Rubirosa Ristorante                     235 Mulberry St
#  8                          by CHLOE.                   1 Rockefeller Plz
#  9                    The Little Beet                       1140 Broadway
#  10             The Little Beet Table                      333 Park Ave S
#  11                Kesté Pizza & Vino                     271 Bleecker St
#  12                      Beyond Sushi                        62 W 56th St
#  13                 The Organic Grill                         123 1st Ave
#  14                        Kimbap Lab                  238 Bedford Avenue
#  15                             S'MAC                         197 1st Ave
#  16              Uno Pizzeria & Grill                     39-02 Bell Blvd
#  17                           Tap NYC                    267 Columbus Ave
#  18                        Hu Kitchen                       78 5th Avenue
#  19        Houdini Kitchen Laboratory                    15-63 Decatur St
#  20                             Noglu                    1266 Madison Ave
#  21                        Exhibit C.                      88 Eldridge St
#  22              Manetta's Ristorante                    1076 Jackson Ave
#  23               Bombay Sandwich Co.                        48 W 27th St
#  24                             Nizza                         630 9th Ave
#  25                Manducatis Rustica                    4635 Vernon Blvd
#  26              Rudy's Bakery & Café                      905 Seneca Ave
#  27                      Senza Gluten                     206 Sullivan St
#  28                             ROLLN                        38 E 23rd St
#  29                           Norma's                   59-02 Catalpa Ave
#  30                         Sweetleaf                   10-93 Jackson Ave
#  31                   The Little Beet                       135 W 50th St
#  32                          Bistango                       145 E 50th St
#  33              UNO Pizzeria & Grill                    432 Columbus Ave
#  34                   The Little Beet                       111 W 40th St
#  35              Paisano's Ristorante                        132 Park Ave
#  36  Davio's North Italian Steakhouse                   447 Lexington Ave
#  37                         Sweetleaf                   28-10 Jackson Ave
#  38     Better Gourmet Health Kitchen                      415 Forest Ave
#  39                    Champion Pizza                                 NaN
#  40                 Bare Naked Bakery                     2572 Merrick Rd
#  41                              Wild                    535 Hudson St #A
#  42              UNO Pizzeria & Grill  426 Route 3 West Riverfront Center
#  43                 Posh Pop Bakeshop                     192 Bleecker St
#  44                FRESH Healthy Cafe                        77 Hudson St
#  45                 The Burger Garage                    2536 Jackson Ave
#  46                    Twibar Falafel                                 NaN
#  47         The Modern Primitive Cafe                         254 36th St
#  48            Capo Ristorante Panino                       49 Covert Ave
#  49             Audrey's Añple Apples                         11 Avenue A
#  50                         Red Mango                      111 Fulton St.
#  51                       Bex Waffles                            Broadway
#  52                              Arba                    472 Columbus Ave
#  53                           Dee Daa                       132 W 31st St
#  54                 Bradley Bake Shop                         55 River Rd
#  55                      Stir-licious                    712 North Avenue
#
#            Lat        Lng
#  0   40.771407 -73.959138
#  1   40.773495 -73.916809
#  2   40.778788 -73.778426
#  3   40.765602 -73.957403
#  4   40.742370 -73.980286
#  5   40.751621 -73.980754
#  6   40.720990 -73.940829
#  7   40.722706 -73.995957
#  8   40.758063 -73.978854
#  9   40.743914 -73.988746
#  10  40.741110 -73.985344
#  11  40.731542 -74.002953
#  12  40.763454 -73.977163
#  13  40.727306 -73.985539
#  14  40.716160 -73.959530
#  15  40.730227 -73.983696
#  16  40.765087 -73.771871
#  17  40.777723 -73.978567
#  18  40.735795 -73.993944
#  19  40.694077 -73.902269
#  20  40.783801 -73.956687
#  21  40.717189 -74.003042
#  22  40.742577 -73.951940
#  23  40.745184 -73.990644
#  24  40.760100 -73.991378
#  25  40.745959 -73.953021
#  26  40.700593 -73.903966
#  27  40.728926 -74.000257
#  28  40.740656 -73.987310
#  29  40.702409 -73.900845
#  30  40.743294 -73.951590
#  31  40.760990 -73.982246
#  32  40.756266 -73.971339
#  33  40.783176 -73.974645
#  34  40.753998 -73.985660
#  35  40.826804 -74.106062
#  36  40.753233 -73.974774
#  37  40.748537 -73.938787
#  38  40.631065 -74.103310
#  39  40.761738 -73.924991
#  40  40.662528 -73.530584
#  41  40.734631 -74.006129
#  42  40.830685 -74.139572
#  43  40.729224 -74.001538
#  44  40.714458 -74.034545
#  45  40.746847 -73.942472
#  46  40.663440 -73.957535
#  47  40.656078 -74.007109
#  48  40.721596 -73.688444
#  49  40.749777 -74.006696
#  50  40.709832 -74.006761
#  51  40.754658 -73.986717
#  52  40.784231 -73.974037
#  53  40.748475 -73.990267
#  54  40.871229 -74.033008
#  55  40.925662 -73.788869  ,
#  'Staten Island':                                         Name  \
#  0                               Panini Grill
#  1              Better Gourmet Health Kitchen
#  2                      CakeChef's Cookie Jar
#  3                           Trattoria Romana
#  4                       UNO Pizzeria & Grill
#  5                        Rubirosa Ristorante
#  6                                  La Piazza
#  7                         Kesté Pizza & Vino
#  8                            Marie's Gourmet
#  9                            The Little Beet
#  10                         The Organic Grill
#  11                     The Little Beet Table
#  12                        One Stop Beer Shop
#  13                                 by CHLOE.
#  14                                Exhibit C.
#  15                                Hu Kitchen
#  16                           The Beer Garden
#  17                                     S'MAC
#  18                              Beyond Sushi
#  19                                  Bistango
#  20                                Kimbap Lab
#  21                               Candle Cafe
#  22                                   Tap NYC
#  23                      Paisano's Ristorante
#  24                             Kome Waza UES
#  25                       Bombay Sandwich Co.
#  26                              Senza Gluten
#  27                                     Nizza
#  28                       Mighty Oak Roasters
#  29                           Pastosa Ravioli
#  30                                     Noglu
#  31                                     ROLLN
#  32        Miller's Ale House - Staten Island
#  33                           Legal Sea Foods
#  34                         Between The Bread
#  35                           Portobello Cafe
#  36                           The Little Beet
#  37                           The Little Beet
#  38                                  Bistango
#  39                      UNO Pizzeria & Grill
#  40                      UNO Pizzeria & Grill
#  41                                      Wild
#  42              Z-Two Diner & Lounge; 24 Hrs
#  43                        FRESH Healthy Cafe
#  44                            Healthy Garden
#  45                           Mondellos Pizza
#  46          Davio's North Italian Steakhouse
#  47                         Posh Pop Bakeshop
#  48  Gino's Villa Monte Pizzeria & Restaurant
#  49                 The Modern Primitive Cafe
#  50                   Mangia! Healthy Kitchen
#  51                            Twibar Falafel
#  52                                 Red Mango
#  53                     Audrey's Añple Apples
#  54                               Bex Waffles
#  55                                      Arba
#  56                                   Dee Daa
#  57                         Bradley Bake Shop
#
#                                 Address        Lat        Lng
#  0                       538 Forest Ave  40.630137 -74.108156
#  1                       415 Forest Ave  40.631065 -74.103310
#  2                      1226 Forest Ave  40.626323 -74.130702
#  3                      1476 Hylan Blvd  40.592354 -74.087181
#  4                         9201 4th Ave  40.618065 -74.030028
#  5                      235 Mulberry St  40.722706 -73.995957
#  6                    1445 Richmond Ave  40.612126 -74.157663
#  7                      271 Bleecker St  40.731542 -74.002953
#  8                     977 Victory Blvd  40.620353 -74.099140
#  9                        1140 Broadway  40.743914 -73.988746
#  10                         123 1st Ave  40.727306 -73.985539
#  11                      333 Park Ave S  40.741110 -73.985344
#  12                   134 Kingsland Ave  40.720990 -73.940829
#  13                   1 Rockefeller Plz  40.758063 -73.978854
#  14                      88 Eldridge St  40.717189 -74.003042
#  15                       78 5th Avenue  40.735795 -73.993944
#  16                   1883 Victory Blvd  40.613010 -74.126524
#  17                         197 1st Ave  40.730227 -73.983696
#  18                        62 W 56th St  40.763454 -73.977163
#  19                         415 3rd Ave  40.742370 -73.980286
#  20                  238 Bedford Avenue  40.716160 -73.959530
#  21                        1307 3rd Ave  40.771407 -73.959138
#  22                    267 Columbus Ave  40.777723 -73.978567
#  23                        132 Park Ave  40.826804 -74.106062
#  24                        1275 1st Ave  40.765602 -73.957403
#  25                        48 W 27th St  40.745184 -73.990644
#  26                     206 Sullivan St  40.728926 -74.000257
#  27                         630 9th Ave  40.760100 -73.991378
#  28                       2801 24th Ave  40.773495 -73.916809
#  29                   3817 Richmond Ave  40.545310 -74.165364
#  30                    1266 Madison Ave  40.783801 -73.956687
#  31                        38 E 23rd St  40.740656 -73.987310
#  32                   2883 Richmond Ave  40.575765 -74.169675
#  33                    1200 Morris Tpke  40.739434 -74.365908
#  34                       20A E 40th St  40.751621 -73.980754
#  35                     4221 Hylan Blvd  40.537290 -74.150628
#  36                       135 W 50th St  40.760990 -73.982246
#  37                       111 W 40th St  40.753998 -73.985660
#  38                       145 E 50th St  40.756266 -73.971339
#  39                    432 Columbus Ave  40.783176 -73.974645
#  40  426 Route 3 West Riverfront Center  40.830685 -74.139572
#  41                    535 Hudson St #A  40.734631 -74.006129
#  42                  2925 Veterans Rd W  40.527291 -74.230811
#  43                        77 Hudson St  40.714458 -74.034545
#  44                                 NaN  40.550922 -74.435063
#  45                  557 Englishtown Rd  40.323467 -74.360908
#  46                   447 Lexington Ave  40.753233 -73.974774
#  47                     192 Bleecker St  40.729224 -74.001538
#  48                     170 New Dorp Ln  40.573322 -74.115242
#  49                         254 36th St  40.656078 -74.007109
#  50                   20 Jefferson Blvd  40.541178 -74.178250
#  51                                 NaN  40.663440 -73.957535
#  52                      111 Fulton St.  40.709832 -74.006761
#  53                         11 Avenue A  40.749777 -74.006696
#  54                            Broadway  40.754658 -73.986717
#  55                    472 Columbus Ave  40.784231 -73.974037
#  56                       132 W 31st St  40.748475 -73.990267
#  57                         55 River Rd  40.871229 -74.033008  }

# %% [markdown]
# The following code is a list of maps named under the variable 'maps' which will allow us to visulaize the number of gluten-free restaurants in each of the 5 different boroughs in NYC

# %%
maps = {}
for bgh in bghs:
    bgh_lat = np.mean([result[bgh]['response']['geocode']['geometry']['bounds']['ne']['lat'],
                        result[bgh]['response']['geocode']['geometry']['bounds']['sw']['lat']])
    bgh_lng = np.mean([result[bgh]['response']['geocode']['geometry']['bounds']['ne']['lng'],
                        result[bgh]['response']['geocode']['geometry']['bounds']['sw']['lng']])
    maps[bgh] = folium.Map(loc = [bgh_lat, bgh_lng], zoom_start = 11)

    # adding markers to the maps
    for lat, lng, label in zip(venues_df[bgh]['Lat'], venues_df[bgh]['Lng'], venues_df[bgh]['Name']):
        label = folium.Popup(label, parse_html = True)
        folium.CircleMarker(
            [lat, lng],
            radius = 5,
            popup = label,
            color = 'purple',
            fill = True,
            fill_color = '#3186cc',
            fill_opacity = 0.7,
            parse_html = False).add_to(maps[bgh])  
    print(f"The number of gluten-free restaurants in {bgh} = ", result[bgh]['response']['totalResults'])
# Out:
# The number of gluten-free restaurants in Bronx =  47
# The number of gluten-free restaurants in Manhattan =  164
# The number of gluten-free restaurants in Brooklyn =  111
# The number of gluten-free restaurants in Queens =  56
# The number of gluten-free restaurants in Staten Island =  58

# %% [markdown]
# Neighborhood | Number of gluten-free restaurants
# --- | ---
# Manhattan | 164
# Brooklyn | 111
# Staten Island | 58
# Queens | 56
# Bronx | 47

# %% [markdown]
# ##### From the results shown above, we can clearly see that Manhattan has highest number of Gluten-free restraunts, followed by Brooklyn and then Staten Island. Note that, the borough having the maximum number of restraunts which is Manhattan, doesn't imply that these are accessible to the tourist. Therefore, we'll have to check for the density in specific boroughs.

# %% [markdown]
# ### Plotting all the borough maps

# %% [markdown]
# Note than bghs[0] - Bronx, bghs[1] - Manhattan, bghs[2] - Brooklyn, bghs[3] - Queens, bghs[4] - Staten Island

# %%
maps[bghs[0]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[bghs[1]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[bghs[2]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[bghs[3]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps[bghs[4]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The following code will show us how close the restraunts are next to each other. For this we will analyse the mean of the distances from the mean of the coordinates.
# To do this, we'll have to first calculate the average of the coordinates i.e. average distance of all coordinates, and then following this, the average of the distances of the restraunts from the mean of the coordinates is calculated.

# %%
maps_analysis = {}
for bgh in bghs:
    bgh_lat = np.mean([result[bgh]['response']['geocode']['geometry']['bounds']['ne']['lat'],
                        result[bgh]['response']['geocode']['geometry']['bounds']['sw']['lat']])
    bgh_lng = np.mean([result[bgh]['response']['geocode']['geometry']['bounds']['ne']['lng'],
                        result[bgh]['response']['geocode']['geometry']['bounds']['sw']['lng']])
    maps_analysis[bgh] = folium.Map(loc = [bgh_lat, bgh_lng], zoom_start = 10)
    venues_mean_coordinates = [venues_df[bgh]['Lat'].mean(), venues_df[bgh]['Lng'].mean()] 
    
    # adding markers to the maps
    for lat, lng, label in zip(venues_df[bgh]['Lat'], venues_df[bgh]['Lng'], venues_df[bgh]['Name']):
        label = folium.Popup(label, parse_html = True)
        folium.CircleMarker(
            [lat, lng],
            radius = 5,
            popup = label,
            color='black',
            fill = True,
            fill_color = '#3186cc',
            fill_opacity = 0.7,
            legend_name = 'borough:'+ bgh,
            parse_html = False).add_to(maps_analysis[bgh])
        folium.PolyLine([venues_mean_coordinates, [lat, lng]], color = "red", weight = 1.5, opacity = 0.5).add_to(maps_analysis[bgh])
    
    label = folium.Popup("Mean Co-ordinate", parse_html = True)
    folium.CircleMarker(
        venues_mean_coordinates,
        radius = 10,
        popup = label,
        color = 'blue',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7,
        caption = ''+bgh,
        parse_html = False).add_to(maps_analysis[bgh])

    a = np.mean(np.apply_along_axis(lambda x: np.linalg.norm(x - venues_mean_coordinates),1,venues_df[bgh][['Lat','Lng']].values))
    print('For the borough',bgh,", the average distance from the average coordinates is : ",a)
# Out:
# For the borough Bronx , the average distance from the average coordinates is :  0.06746237034747092
# For the borough Manhattan , the average distance from the average coordinates is :  0.022651830023089826
# For the borough Brooklyn , the average distance from the average coordinates is :  0.03232477411760373
# For the borough Queens , the average distance from the average coordinates is :  0.06808135560349733
# For the borough Staten Island , the average distance from the average coordinates is :  0.11618800772126377

# %% [markdown]
# Neighborhood | Average Distance
# --- | ---
# Manhattan | 0.022651830023089826
# Brooklyn | 0.03232477411760373
# Bronx | 0.06746237034747092
# Queens | 0.06808135560349733
# Staten Island | 0.11618800772126377

# %% [markdown]
# ### From the above results, it is clear that the restaurants are most densely populated in Manhattan, followed by Brooklyn and finally Bronx. Also notice that the average distance of the boroughs Bronx and Brooklyn does'nt have much of a significant difference in their values. However, the results obtained above conclude that the borough Manhattan would be a perfect choice for the Gluten-allergic tourists visiting NYC since this borough is not only densely populated but the average distance from the average coordinates is also really small compared to the other borough average distances.

# %% [markdown]
# ##### Now we'll be plotting the maps of each of the various boroughs in order to visualize the average distances. This is stored in the variable 'maps_analysis'

# %%
maps_analysis[bghs[0]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps_analysis[bghs[1]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps_analysis[bghs[2]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps_analysis[bghs[3]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
maps_analysis[bghs[4]]
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### We see that in boroughs Bronx, Queens and Staten Island, there are 3, 7 and 3 outliers respectively. This might affect our results, hence its safe to remove them before concluding anything.

# %%
bgh = 'Bronx'
venues_mean_coordinates = [venues_df[bgh]['Lat'].mean(), venues_df[bgh]['Lng'].mean()] 

print(bgh)
print("Mean Distance from Mean coordinates")
dist = np.apply_along_axis(lambda x: np.linalg.norm(x - venues_mean_coordinates),1,venues_df[bgh][['Lat','Lng']].values)
dist.sort()
print(np.mean(dist[:-3]))# Ignoromg the 3 biggest distance
# Out:
# Bronx
# Mean Distance from Mean coordinates
# 0.053565619863168656

# %%
bgh = 'Queens'
venues_mean_coordinates = [venues_df[bgh]['Lat'].mean(), venues_df[bgh]['Lng'].mean()] 

print(bgh)
print("Mean Distance from Mean coordinates")
dist = np.apply_along_axis(lambda x: np.linalg.norm(x - venues_mean_coordinates),1,venues_df[bgh][['Lat','Lng']].values)
dist.sort()
print(np.mean(dist[:-7]))# Ignoromg the 7 biggest distance
# Out:
# Queens
# Mean Distance from Mean coordinates
# 0.04293349210337712

# %%
bgh = 'Staten Island'
venues_mean_coordinates = [venues_df[bgh]['Lat'].mean(), venues_df[bgh]['Lng'].mean()] 

print(bgh)
print("Mean Distance from Mean coordinates")
dist = np.apply_along_axis(lambda x: np.linalg.norm(x - venues_mean_coordinates),1,venues_df[bgh][['Lat','Lng']].values)
dist.sort()
print(np.mean(dist[:-3]))# Ignoromg the 5 biggest distances
# Out:
# Staten Island
# Mean Distance from Mean coordinates
# 0.10015259081593658

# %% [markdown]
# The final table of our average distances would look like :

# %% [markdown]
# Neighborhood | Average Distance
# --- | ---
# Manhattan | 0.022651830023089826
# Brooklyn | 0.03232477411760373
# Queens | 0.04293349210337712
# Bronx | 0.053565619863168656
# Staten Island | 0.10015259081593658

# %% [markdown]
# Rank before | avg dist before | Rank after | avg dist after
# --- | --- | ---| ---
# Manhattan | 0.02265 | Manhattan | 0.02265
# Brooklyn | 0.032324 | Brooklyn | 0.032324
# Bronx | 0.06746 | Queens | 0.042933
# Queens | 0.06808 | Bronx | 0.053565
# Staten Island | 0.100152 | Staten Island | 0.100152

# %% [markdown]
# ### From the above results, even after the removal of outliers, we are sure of our results and we can hence conclude that Manhattan is the perfect choice for a gluten-allergic person.
